# %% [markdown]
# <a href="https://colab.research.google.com/github/Chithra05/Projects/blob/main/Searching_for_similar_images_to_an_input_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from ipython-autotime) (5.5.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (0.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->ipython-autotime) (5.1.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->ipython-autotime) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->ipython-autotime) (0.7.0)
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.3.1
# time: 2.31 ms (started: 2021-10-01 07:52:06 +00:00)

# %%
# !pip install bing-image-downloader
# Out:
# Collecting bing-image-downloader
#   Downloading bing_image_downloader-1.1.1-py3-none-any.whl (5.7 kB)
# Installing collected packages: bing-image-downloader
# Successfully installed bing-image-downloader-1.1.1
# time: 3.13 s (started: 2021-10-01 07:52:14 +00:00)

# %%
# !mkdir images
# Out:
# time: 128 ms (started: 2021-10-01 07:52:27 +00:00)

# %%
from bing_image_downloader import downloader
downloader.download("pretty roses",limit=30,output_dir='images',
                    adult_filter_off=True)
# Out:
# [%] Downloading Images to /content/images/pretty roses
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/6a/78/d0/6a78d0a836b96f975d6c5e338ae75727.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/43/75/5c/43755cc23d594b0fa00fed74f6d30839.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/67/92/43/6792430048d6a20f9caaea748b005927.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/35/fe/ed/35feed534a62d8ca6546523e0dc8c5a4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/736x/3a/85/b2/3a85b22872cddf4f13c9434643a04fac.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.pinimg.com/originals/4f/25/08/4f2508f998ec187ee62e6c27ecc2ed2c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://i.pinimg.com/originals/eb/3c/e5/eb3ce5ed74d42f0e2e5fd24ab7ebf97b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://i.pinimg.com/originals/ee/b8/93/eeb8938c6013f68ddf2a9a6613d18160.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://i.pinimg.com/originals/5d/19/89/5d1989ebbe215d5bae5d3fcdc00c88a9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://i.pinimg.com/originals/7e/e3/20/7ee3202f8c4a2007865a15848f9fabce.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://i.pinimg.com/originals/11/43/c2/1143c20517215ed63260017ee8d4c316.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://i.pinimg.com/originals/12/46/ad/1246adaa6dfb5cb6f917cdf7a3a2e14b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://i.pinimg.com/originals/95/1b/af/951baf67ddcbdaac59b7e7d803a2461b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://i.pinimg.com/originals/a2/bc/31/a2bc31645d95a5ea064b8374e0cf89a1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://i.pinimg.com/originals/3b/3b/15/3b3b152ac8b643a5bc26c0773646f8ff.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https://i.pinimg.com/originals/fd/1e/de/fd1ede11d86da758329c497e736fd709.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://i.pinimg.com/originals/c3/53/f2/c353f26a042ef9686e2e0a1bc21789f1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://i.pinimg.com/originals/f8/63/be/f863be2307dcbb2d364f4d8a1fedc4ea.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://res.cloudinary.com/bloomnation/c_pad,d_vendor:global:catalog:product:image.png,f_auto,fl_preserve_transparency,q_auto/v1582065462/vendor/2961/catalog/product/2/0/20150124123713_file_54c391f9051a6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://i.pinimg.com/originals/6d/8c/16/6d8c1635945a22c15c5e792c8d4bbb92.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://i.pinimg.com/originals/3e/43/f6/3e43f62040e32c355bb1eb883c07d7a9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://i.pinimg.com/originals/0c/7c/82/0c7c82f8f6002947b7cf26281f11cb65.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://i.pinimg.com/736x/6b/1f/c5/6b1fc59c13aa380bb9e59d09be053ab9--dream-come-true-secret-gardens.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://i.pinimg.com/originals/00/fe/be/00febe421862e8c77b4dfb490bb67bb1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://s-media-cache-ak0.pinimg.com/564x/f2/01/57/f201574c8705365b2c3e182953f765f2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://i.pinimg.com/originals/94/1c/24/941c24f846805ba95e79d19c32064f9b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://i.pinimg.com/originals/df/72/ad/df72ad73cbe9ad67352eacd77932b54d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://i.pinimg.com/originals/ed/0f/d5/ed0fd5cfb545e294f3c28bd5aefeeab4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://i.pinimg.com/originals/4f/cb/9b/4fcb9ba2f1b18df905f66cb47133ad72.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://i.pinimg.com/originals/5d/6d/a2/5d6da206f4261b65ee862a0eba85d09b.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 30 images.
# ===============================================
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ===============================================
#
# time: 6.43 s (started: 2021-10-01 07:52:50 +00:00)

# %%
# !pip install DeepImageSearch -q
# Out:
#      |████████████████████████████████| 646 kB 6.7 MB/s
#   Building wheel for DeepImageSearch (setup.py) ... done
#   Building wheel for annoy (setup.py) ... done
# time: 13 s (started: 2021-10-01 07:53:09 +00:00)

# %%
import numpy as np
import pandas as pd
# Out:
# time: 1.1 ms (started: 2021-10-01 07:53:59 +00:00)

# %%
from DeepImageSearch import Index,LoadData,SearchImage
# Out:
# time: 2.1 s (started: 2021-10-01 07:54:49 +00:00)

# %%
image_list = LoadData().from_folder(folder_list = ['/content/images/pretty roses'])
# Out:
# time: 4.69 ms (started: 2021-10-01 08:03:58 +00:00)

# %%
Index(image_list).Start()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 5s 0us/step
# 553476096/553467096 [==============================] - 5s 0us/step
# 100%|██████████| 30/30 [00:17<00:00,  1.67it/s]
# Image Meta Information Saved: [meta-data-files/image_data_features.pkl]
# 30it [00:00, 1181.63it/s]
# Saved the Indexed File:[meta-data-files/image_features_vectors.ann]
# time: 25.5 s (started: 2021-10-01 08:06:00 +00:00)

# %%
image_list[0]
# Out:
# '/content/images/pretty roses/Image_27.jpg'
# time: 5.76 ms (started: 2021-10-01 08:12:41 +00:00)

# %%
SearchImage().get_similar_images(image_path='/content/images/pretty roses/Image_1.jpg',number_of_images=5)
# Out:
# {4: '/content/images/pretty roses/Image_30.jpg',
#  6: '/content/images/pretty roses/Image_1.jpg',
#  8: '/content/images/pretty roses/Image_15.jpg',
#  12: '/content/images/pretty roses/Image_29.jpg',
#  16: '/content/images/pretty roses/Image_18.jpg'}
# time: 3.07 s (started: 2021-10-01 08:19:43 +00:00)

# %%
SearchImage().plot_similar_images(image_path = '/content/images/pretty roses/Image_1.jpg')
# Out:
# time: 8.34 s (started: 2021-10-01 08:19:59 +00:00)
